# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report

# %%
texts = ["troll2 is great", "gymkata is great", "this movie is bad", "I don't like this film"]
labels = [1, 1, 0, 0]  # 1: positive, 0: negative

# Tokenization
max_words = 1000  # Maximum number of words in the vocabulary
max_len = 10  # Maximum sentence length

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

data = pad_sequences(sequences, maxlen=max_len)
labels = np.array(labels)

# %%
# X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.25, random_state=42)

# Build a simple CNN model
embedding_dim = 50

model = Sequential()
embedding_layer = Embedding(input_dim=max_words, output_dim=embedding_dim)
model.add(embedding_layer)
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_10         │ ?                      │   0 (unbuilt) │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
def plot_embeddings(embeddings, word_index, title):
    words = list(word_index.keys())[:100]  # limit to first 100 words for clarity
    vectors = embeddings[1:len(words) + 1]  # Skip the zero padding index (index 0)

    tsne = TSNE(n_components=2, random_state=42)
    reduced_vectors = tsne.fit_transform(vectors)

    plt.figure(figsize=(10, 8))
    for i, word in enumerate(words):
        plt.scatter(reduced_vectors[i, 0], reduced_vectors[i, 1])
        plt.annotate(word, (reduced_vectors[i, 0], reduced_vectors[i, 1]))
    plt.title(title)
    plt.show()

# %%
embeddings_before = embedding_layer.get_weights()[0]

# Plot word embeddings before training
plot_embeddings(embeddings_before, word_index, title="Word Embeddings Before Training")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 embeddings_before = embedding_layer.get_weights()[0]
#       3 # Plot word embeddings before training
#       4 plot_embeddings(embeddings_before, word_index, title="Word Embeddings Before Training")
#
# IndexError: list index out of range

# %%
history = model.fit(X_train, y_train, epochs=60, batch_size=2, validation_data=(X_val, y_val), verbose=2)
# Out:
# Epoch 1/60
# 2/2 - 3s - 1s/step - accuracy: 0.6667 - loss: 0.6540 - val_accuracy: 0.0000e+00 - val_loss: 0.7592
# Epoch 2/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.6913 - val_accuracy: 0.0000e+00 - val_loss: 0.7713
# Epoch 3/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.7110 - val_accuracy: 0.0000e+00 - val_loss: 0.7767
# Epoch 4/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.6818 - val_accuracy: 0.0000e+00 - val_loss: 0.7805
# Epoch 5/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.5616 - val_accuracy: 0.0000e+00 - val_loss: 0.7872
# Epoch 6/60
# 2/2 - 0s - 40ms/step - accuracy: 0.6667 - loss: 0.6319 - val_accuracy: 0.0000e+00 - val_loss: 0.7952
# Epoch 7/60
# 2/2 - 0s - 45ms/step - accuracy: 0.6667 - loss: 0.5363 - val_accuracy: 0.0000e+00 - val_loss: 0.7993
# Epoch 8/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.5288 - val_accuracy: 0.0000e+00 - val_loss: 0.7873
# Epoch 9/60
# 2/2 - 0s - 45ms/step - accuracy: 0.6667 - loss: 0.5428 - val_accuracy: 0.0000e+00 - val_loss: 0.7774
# Epoch 10/60
# 2/2 - 0s - 40ms/step - accuracy: 0.6667 - loss: 0.5319 - val_accuracy: 0.0000e+00 - val_loss: 0.7682
# Epoch 11/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.6628 - val_accuracy: 0.0000e+00 - val_loss: 0.7648
# Epoch 12/60
# 2/2 - 0s - 40ms/step - accuracy: 0.6667 - loss: 0.4047 - val_accuracy: 0.0000e+00 - val_loss: 0.7674
# Epoch 13/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.4025 - val_accuracy: 0.0000e+00 - val_loss: 0.7769
# Epoch 14/60
# 2/2 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.5448 - val_accuracy: 0.0000e+00 - val_loss: 0.7881
# Epoch 15/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.3703 - val_accuracy: 0.0000e+00 - val_loss: 0.8016
# Epoch 16/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.3586 - val_accuracy: 0.0000e+00 - val_loss: 0.8115
# Epoch 17/60
# 2/2 - 0s - 40ms/step - accuracy: 0.6667 - loss: 0.4622 - val_accuracy: 0.0000e+00 - val_loss: 0.8186
# Epoch 18/60
# 2/2 - 0s - 40ms/step - accuracy: 0.6667 - loss: 0.4330 - val_accuracy: 0.0000e+00 - val_loss: 0.8287
# Epoch 19/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.3950 - val_accuracy: 0.0000e+00 - val_loss: 0.8444
# Epoch 20/60
# 2/2 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.5252 - val_accuracy: 0.0000e+00 - val_loss: 0.8564
# Epoch 21/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.3809 - val_accuracy: 0.0000e+00 - val_loss: 0.8541
# Epoch 22/60
# 2/2 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.2772 - val_accuracy: 0.0000e+00 - val_loss: 0.8553
# Epoch 23/60
# 2/2 - 0s - 42ms/step - accuracy: 0.6667 - loss: 0.3468 - val_accuracy: 0.0000e+00 - val_loss: 0.8628
# Epoch 24/60
# 2/2 - 0s - 42ms/step - accuracy: 0.6667 - loss: 0.2966 - val_accuracy: 0.0000e+00 - val_loss: 0.8684
# Epoch 25/60
# 2/2 - 0s - 42ms/step - accuracy: 0.6667 - loss: 0.5821 - val_accuracy: 0.0000e+00 - val_loss: 0.8745
# Epoch 26/60
# 2/2 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.3961 - val_accuracy: 0.0000e+00 - val_loss: 0.8817
# Epoch 27/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.3253 - val_accuracy: 0.0000e+00 - val_loss: 0.8838
# Epoch 28/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.3097 - val_accuracy: 0.0000e+00 - val_loss: 0.8884
# Epoch 29/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.5734 - val_accuracy: 0.0000e+00 - val_loss: 0.8876
# Epoch 30/60
# 2/2 - 0s - 42ms/step - accuracy: 0.6667 - loss: 0.2601 - val_accuracy: 0.0000e+00 - val_loss: 0.8778
# Epoch 31/60
# 2/2 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.2230 - val_accuracy: 0.0000e+00 - val_loss: 0.8646
# Epoch 32/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.3002 - val_accuracy: 0.0000e+00 - val_loss: 0.8501
# Epoch 33/60
# 2/2 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.3265 - val_accuracy: 0.0000e+00 - val_loss: 0.8331
# Epoch 34/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.2111 - val_accuracy: 0.0000e+00 - val_loss: 0.8159
# Epoch 35/60
# 2/2 - 0s - 42ms/step - accuracy: 0.6667 - loss: 0.3568 - val_accuracy: 0.0000e+00 - val_loss: 0.8011
# Epoch 36/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.2402 - val_accuracy: 0.0000e+00 - val_loss: 0.7915
# Epoch 37/60
# 2/2 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.2172 - val_accuracy: 0.0000e+00 - val_loss: 0.7837
# Epoch 38/60
# 2/2 - 0s - 46ms/step - accuracy: 0.6667 - loss: 0.2727 - val_accuracy: 0.0000e+00 - val_loss: 0.7799
# Epoch 39/60
# 2/2 - 0s - 53ms/step - accuracy: 1.0000 - loss: 0.4236 - val_accuracy: 0.0000e+00 - val_loss: 0.7775
# Epoch 40/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.3563 - val_accuracy: 0.0000e+00 - val_loss: 0.7829
# Epoch 41/60
# 2/2 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.1512 - val_accuracy: 0.0000e+00 - val_loss: 0.7857
# Epoch 42/60
# 2/2 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.1989 - val_accuracy: 0.0000e+00 - val_loss: 0.7812
# Epoch 43/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.1000 - val_accuracy: 0.0000e+00 - val_loss: 0.7724
# Epoch 44/60
# 2/2 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.1569 - val_accuracy: 0.0000e+00 - val_loss: 0.7607
# Epoch 45/60
# 2/2 - 0s - 44ms/step - accuracy: 0.6667 - loss: 0.2536 - val_accuracy: 0.0000e+00 - val_loss: 0.7523
# Epoch 46/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.2785 - val_accuracy: 0.0000e+00 - val_loss: 0.7493
# Epoch 47/60
# 2/2 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.1771 - val_accuracy: 0.0000e+00 - val_loss: 0.7486
# Epoch 48/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.1699 - val_accuracy: 0.0000e+00 - val_loss: 0.7441
# Epoch 49/60
# 2/2 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.3149 - val_accuracy: 0.0000e+00 - val_loss: 0.7363
# Epoch 50/60
# 2/2 - 0s - 43ms/step - accuracy: 0.6667 - loss: 0.2529 - val_accuracy: 0.0000e+00 - val_loss: 0.7333
# Epoch 51/60
# 2/2 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.2098 - val_accuracy: 0.0000e+00 - val_loss: 0.7277
# Epoch 52/60
# 2/2 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.1202 - val_accuracy: 0.0000e+00 - val_loss: 0.7221
# Epoch 53/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.1344 - val_accuracy: 0.0000e+00 - val_loss: 0.7136
# Epoch 54/60
# 2/2 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.2654 - val_accuracy: 0.0000e+00 - val_loss: 0.7005
# Epoch 55/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.2506 - val_accuracy: 1.0000 - val_loss: 0.6841
# Epoch 56/60
# 2/2 - 0s - 41ms/step - accuracy: 0.6667 - loss: 0.3498 - val_accuracy: 1.0000 - val_loss: 0.6656
# Epoch 57/60
# 2/2 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.0515 - val_accuracy: 1.0000 - val_loss: 0.6504
# Epoch 58/60
# 2/2 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.1531 - val_accuracy: 1.0000 - val_loss: 0.6387
# Epoch 59/60
# 2/2 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.1525 - val_accuracy: 1.0000 - val_loss: 0.6257
# Epoch 60/60
# 2/2 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.1268 - val_accuracy: 1.0000 - val_loss: 0.6118

# %%
val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f'Validation Accuracy: {val_accuracy:.4f}, Validation Loss: {val_loss:.4f}')
# Out:
# Validation Accuracy: 1.0000, Validation Loss: 0.6118

# %%
new_texts = ["is don't great", "gymkata is great", "this movie is bad", "I don't like this film"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_data = pad_sequences(new_sequences, maxlen=max_len)

# %%
predictions = model.predict(new_data)
predictions_binary = (predictions > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step

# %%
print("Predictions:", predictions_binary.flatten())
print("Classification Report:")
# print(classification_report([1, 0], predictions_binary.flatten(), target_names=['Negative', 'Positive']))
# Out:
# Predictions: [0 1 0 0]
# Classification Report:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample data
texts = ["troll2 is great", "gymkata is great","this ia a good movie", "this movie is bad", "I don't like this film"]
labels = [1, 1,1, 0, 0]  # 1: positive, 0: negative

# Tokenization
max_words = 1000  # Maximum number of words in the vocabulary
max_len = 10  # Maximum sentence length

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

data = pad_sequences(sequences, maxlen=max_len)
labels = np.array(labels)

# Build a simple CNN model
embedding_dim = 50

model = Sequential()
embedding_layer = Embedding(input_dim=max_words, output_dim=embedding_dim)
model.add(embedding_layer)
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Perform a single forward pass to initialize the embeddings
model.train_on_batch(data, labels)  # Run a single batch training step

# Function to plot embeddings
def plot_embeddings(embeddings, word_index, title):
    words = list(word_index.keys())[:30]  # Limit to first 30 words for clarity
    vectors = embeddings[1:len(words) + 1]  # Skip the zero padding index (index 0)

    # Set perplexity less than the number of samples
    tsne = TSNE(n_components=2, perplexity=min(5, len(vectors) - 1), random_state=42)
    reduced_vectors = tsne.fit_transform(vectors)

    plt.figure(figsize=(10, 8))
    for i, word in enumerate(words):
        plt.scatter(reduced_vectors[i, 0], reduced_vectors[i, 1])
        plt.annotate(word, (reduced_vectors[i, 0], reduced_vectors[i, 1]))
    plt.title(title)
    plt.show()

# Get embeddings before training
embeddings_before = embedding_layer.get_weights()[0]

# Plot word embeddings before training
plot_embeddings(embeddings_before, word_index, title="Word Embeddings Before Training")

# Train the model
model.fit(data, labels, epochs=100, batch_size=2, verbose=2)

# Get embeddings after training
embeddings_after = embedding_layer.get_weights()[0]

# Plot word embeddings after training
plot_embeddings(embeddings_after, word_index, title="Word Embeddings After Training")
# Out:
# Epoch 1/100
# 3/3 - 1s - 334ms/step - accuracy: 0.8000 - loss: 0.6840
# Epoch 2/100
# 3/3 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.6631
# Epoch 3/100
# 3/3 - 0s - 15ms/step - accuracy: 0.2000 - loss: 0.6919
# Epoch 4/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.6356
# Epoch 5/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.6515
# Epoch 6/100
# 3/3 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.5931
# Epoch 7/100
# 3/3 - 0s - 15ms/step - accuracy: 0.6000 - loss: 0.6473
# Epoch 8/100
# 3/3 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.5618
# Epoch 9/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.5551
# Epoch 10/100
# 3/3 - 0s - 16ms/step - accuracy: 0.8000 - loss: 0.5712
# Epoch 11/100
# 3/3 - 0s - 20ms/step - accuracy: 1.0000 - loss: 0.5705
# Epoch 12/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.5176
# Epoch 13/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.4927
# Epoch 14/100
# 3/3 - 0s - 16ms/step - accuracy: 0.4000 - loss: 0.6119
# Epoch 15/100
# 3/3 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.4352
# Epoch 16/100
# 3/3 - 0s - 18ms/step - accuracy: 0.6000 - loss: 0.4620
# Epoch 17/100
# 3/3 - 0s - 23ms/step - accuracy: 1.0000 - loss: 0.3287
# Epoch 18/100
# 3/3 - 0s - 21ms/step - accuracy: 0.8000 - loss: 0.3952
# Epoch 19/100
# 3/3 - 0s - 19ms/step - accuracy: 0.8000 - loss: 0.4016
# Epoch 20/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.3627
# Epoch 21/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.2548
# Epoch 22/100
# 3/3 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.2601
# Epoch 23/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.4003
# Epoch 24/100
# 3/3 - 0s - 18ms/step - accuracy: 0.8000 - loss: 0.4931
# Epoch 25/100
# 3/3 - 0s - 23ms/step - accuracy: 1.0000 - loss: 0.2604
# Epoch 26/100
# 3/3 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.2817
# Epoch 27/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.3078
# Epoch 28/100
# 3/3 - 0s - 20ms/step - accuracy: 1.0000 - loss: 0.2189
# Epoch 29/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.2075
# Epoch 30/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.1358
# Epoch 31/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.3116
# Epoch 32/100
# 3/3 - 0s - 16ms/step - accuracy: 0.8000 - loss: 0.2430
# Epoch 33/100
# 3/3 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.2660
# Epoch 34/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.3513
# Epoch 35/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.2279
# Epoch 36/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.2876
# Epoch 37/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.1604
# Epoch 38/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0868
# Epoch 39/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.3720
# Epoch 40/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.1198
# Epoch 41/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.3012
# Epoch 42/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0570
# Epoch 43/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 44/100
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0734
# Epoch 45/100
# 3/3 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.1789
# Epoch 46/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0622
# Epoch 47/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.3106
# Epoch 48/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.2770
# Epoch 49/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 50/100
# 3/3 - 0s - 17ms/step - accuracy: 0.8000 - loss: 0.1521
# Epoch 51/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.1673
# Epoch 52/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 53/100
# 3/3 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.0442
# Epoch 54/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.1682
# Epoch 55/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.1646
# Epoch 56/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 57/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.2770
# Epoch 58/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.2607
# Epoch 59/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.0352
# Epoch 60/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.2913
# Epoch 61/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.1978
# Epoch 62/100
# 3/3 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.1589
# Epoch 63/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.3030
# Epoch 64/100
# 3/3 - 0s - 14ms/step - accuracy: 0.8000 - loss: 0.1622
# Epoch 65/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1347
# Epoch 66/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1748
# Epoch 67/100
# 3/3 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.1475
# Epoch 68/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 69/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0473
# Epoch 70/100
# 3/3 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 71/100
# 3/3 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 72/100
# 3/3 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1373
# Epoch 73/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1426
# Epoch 74/100
# 3/3 - 0s - 14ms/step - accuracy: 0.8000 - loss: 0.3009
# Epoch 75/100
# 3/3 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.0155
# Epoch 76/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 77/100
# 3/3 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1330
# Epoch 78/100
# 3/3 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1551
# Epoch 79/100
# 3/3 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1331
# Epoch 80/100
# 3/3 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.2692
# Epoch 81/100
# 3/3 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 82/100
# 3/3 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 83/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1425
# Epoch 84/100
# 3/3 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.2698
# Epoch 85/100
# 3/3 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1255
# Epoch 86/100
# 3/3 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.2759
# Epoch 87/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 88/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 89/100
# 3/3 - 0s - 11ms/step - accuracy: 0.8000 - loss: 0.4091
# Epoch 90/100
# 3/3 - 0s - 12ms/step - accuracy: 0.8000 - loss: 0.4162
# Epoch 91/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1479
# Epoch 92/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 93/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 94/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1357
# Epoch 95/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1440
# Epoch 96/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1314
# Epoch 97/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.2646
# Epoch 98/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.2663
# Epoch 99/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1361
# Epoch 100/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1307

# %%
new_texts = ["is don't great", "gymkata is great", "this movie is bad", "I don't like this film"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_data = pad_sequences(new_sequences, maxlen=max_len)

predictions = model.predict(new_data)
predictions_binary = (predictions > 0.5).astype(int)

print("Predictions:", predictions_binary.flatten())
print("Classification Report:")
# print(classification_report([1, 0], predictions_binary.flatten(), target_names=['Negative', 'Positive']))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Predictions: [0 1 0 0]
# Classification Report:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import Callback
import matplotlib.animation as animation

# Sample data
texts = ["troll2 is great", "gymkata is great", "this is a good movie", "this movie is bad", "I don't like this film"]
labels = [1, 1, 1, 0, 0]  # 1: positive, 0: negative

# Tokenization
max_words = 1000  # Maximum number of words in the vocabulary
max_len = 10  # Maximum sentence length

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

data = pad_sequences(sequences, maxlen=max_len)
labels = np.array(labels)

# Build a simple CNN model
embedding_dim = 50

model = Sequential()
embedding_layer = Embedding(input_dim=max_words, output_dim=embedding_dim)
model.add(embedding_layer)
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Custom callback to save embeddings at each epoch
class EmbeddingLogger(Callback):
    def __init__(self, embedding_layer, word_index, interval=1):
        super().__init__()
        self.embedding_layer = embedding_layer
        self.word_index = word_index
        self.interval = interval
        self.embeddings_history = []

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.interval == 0:  # Save embeddings every `interval` epochs
            embeddings = self.embedding_layer.get_weights()[0]
            self.embeddings_history.append((epoch, embeddings))

# Create callback instance
embedding_logger = EmbeddingLogger(embedding_layer, word_index, interval=1)

# Train the model with callback
model.fit(data, labels, epochs=100, batch_size=2, verbose=2, callbacks=[embedding_logger])

# Generate frames for animation
fig, ax = plt.subplots(figsize=(10, 8))

def update_plot(frame):
    ax.clear()  # Clear the previous frame
    epoch, embeddings = frame

    words = list(word_index.keys())[:30]  # Limit to first 30 words for clarity
    vectors = embeddings[1:len(words) + 1]  # Skip the zero padding index (index 0)

    # Set perplexity less than the number of samples
    tsne = TSNE(n_components=2, perplexity=min(5, len(vectors) - 1), random_state=42)
    reduced_vectors = tsne.fit_transform(vectors)

    for i, word in enumerate(words):
        ax.scatter(reduced_vectors[i, 0], reduced_vectors[i, 1])
        ax.annotate(word, (reduced_vectors[i, 0], reduced_vectors[i, 1]))
    ax.set_title(f"Word Embeddings Evolution - Epoch {epoch}")
    ax.grid(True)

# Create animation
ani = animation.FuncAnimation(fig, update_plot, frames=embedding_logger.embeddings_history, repeat=False)

# Save the animation as a GIF
ani.save('embeddings_evolution.gif', writer='pillow', fps=5)  # Save as GIF

plt.show()
# Out:
# Epoch 1/100
# 3/3 - 1s - 312ms/step - accuracy: 0.4000 - loss: 0.7060
# Epoch 2/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.6922
# Epoch 3/100
# 3/3 - 0s - 10ms/step - accuracy: 0.6000 - loss: 0.6947
# Epoch 4/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.6836
# Epoch 5/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.6774
# Epoch 6/100
# 3/3 - 0s - 9ms/step - accuracy: 0.6000 - loss: 0.6817
# Epoch 7/100
# 3/3 - 0s - 9ms/step - accuracy: 0.6000 - loss: 0.6728
# Epoch 8/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.6756
# Epoch 9/100
# 3/3 - 0s - 10ms/step - accuracy: 0.6000 - loss: 0.6693
# Epoch 10/100
# 3/3 - 0s - 10ms/step - accuracy: 0.6000 - loss: 0.6664
# Epoch 11/100
# 3/3 - 0s - 11ms/step - accuracy: 0.6000 - loss: 0.6605
# Epoch 12/100
# 3/3 - 0s - 8ms/step - accuracy: 0.6000 - loss: 0.6521
# Epoch 13/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.6536
# Epoch 14/100
# 3/3 - 0s - 9ms/step - accuracy: 0.6000 - loss: 0.6353
# Epoch 15/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.6088
# Epoch 16/100
# 3/3 - 0s - 9ms/step - accuracy: 0.4000 - loss: 0.6263
# Epoch 17/100
# 3/3 - 0s - 8ms/step - accuracy: 0.8000 - loss: 0.6243
# Epoch 18/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.5731
# Epoch 19/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.5656
# Epoch 20/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.5403
# Epoch 21/100
# 3/3 - 0s - 8ms/step - accuracy: 0.8000 - loss: 0.5818
# Epoch 22/100
# 3/3 - 0s - 8ms/step - accuracy: 0.8000 - loss: 0.5108
# Epoch 23/100
# 3/3 - 0s - 8ms/step - accuracy: 0.6000 - loss: 0.5966
# Epoch 24/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.5309
# Epoch 25/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.6003
# Epoch 26/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.3866
# Epoch 27/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3966
# Epoch 28/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.4389
# Epoch 29/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3267
# Epoch 30/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.3071
# Epoch 31/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.4263
# Epoch 32/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.2093
# Epoch 33/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.2767
# Epoch 34/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.2567
# Epoch 35/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.4055
# Epoch 36/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3325
# Epoch 37/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.3147
# Epoch 38/100
# 3/3 - 0s - 9ms/step - accuracy: 0.6000 - loss: 0.3054
# Epoch 39/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.3727
# Epoch 40/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0836
# Epoch 41/100
# 3/3 - 0s - 8ms/step - accuracy: 0.8000 - loss: 0.3147
# Epoch 42/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.3530
# Epoch 43/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2569
# Epoch 44/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1115
# Epoch 45/100
# 3/3 - 0s - 8ms/step - accuracy: 0.6000 - loss: 0.3201
# Epoch 46/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1770
# Epoch 47/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0881
# Epoch 48/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1071
# Epoch 49/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.2400
# Epoch 50/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.1633
# Epoch 51/100
# 3/3 - 0s - 11ms/step - accuracy: 0.8000 - loss: 0.1782
# Epoch 52/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0951
# Epoch 53/100
# 3/3 - 0s - 8ms/step - accuracy: 0.4000 - loss: 0.4571
# Epoch 54/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.2880
# Epoch 55/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.2910
# Epoch 56/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.2870
# Epoch 57/100
# 3/3 - 0s - 11ms/step - accuracy: 0.6000 - loss: 0.2985
# Epoch 58/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0911
# Epoch 59/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1860
# Epoch 60/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0503
# Epoch 61/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1653
# Epoch 62/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.3247
# Epoch 63/100
# 3/3 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.2406
# Epoch 64/100
# 3/3 - 0s - 11ms/step - accuracy: 0.8000 - loss: 0.3223
# Epoch 65/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0799
# Epoch 66/100
# 3/3 - 0s - 10ms/step - accuracy: 0.4000 - loss: 0.4229
# Epoch 67/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.3009
# Epoch 68/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.1778
# Epoch 69/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.1413
# Epoch 70/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.1711
# Epoch 71/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1469
# Epoch 72/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0494
# Epoch 73/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.1521
# Epoch 74/100
# 3/3 - 0s - 10ms/step - accuracy: 0.6000 - loss: 0.2794
# Epoch 75/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1972
# Epoch 76/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0305
# Epoch 77/100
# 3/3 - 0s - 11ms/step - accuracy: 0.8000 - loss: 0.1740
# Epoch 78/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1628
# Epoch 79/100
# 3/3 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 80/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.1421
# Epoch 81/100
# 3/3 - 0s - 8ms/step - accuracy: 0.6000 - loss: 0.2774
# Epoch 82/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1551
# Epoch 83/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 84/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 85/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1586
# Epoch 86/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 87/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 88/100
# 3/3 - 0s - 9ms/step - accuracy: 0.8000 - loss: 0.2886
# Epoch 89/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0158
# Epoch 90/100
# 3/3 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 91/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1392
# Epoch 92/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 6.2862e-04
# Epoch 93/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 94/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1398
# Epoch 95/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 96/100
# 3/3 - 0s - 10ms/step - accuracy: 0.8000 - loss: 0.2904
# Epoch 97/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 98/100
# 3/3 - 0s - 9ms/step - accuracy: 1.0000 - loss: 4.4340e-04
# Epoch 99/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 100/100
# 3/3 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0041
